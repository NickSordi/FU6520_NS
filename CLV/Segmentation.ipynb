# %%
import pandas as pd

# %%
df = pd.read_csv('Encoded_CreditCard_Data.csv')

# %%
exsisting = df[df['Attrition_Flag'] == 1]

# %%
exsisting.drop('CLIENTNUM', axis=1, inplace=True)
# Out:
# C:\Users\nfs25\AppData\Local\Temp\ipykernel_22760\2001492293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exsisting.drop('CLIENTNUM', axis=1, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df is your DataFrame and you want to normalize column 'A'
scaler = MinMaxScaler()

# Note that MinMaxScaler expects a 2D array so we use df[['A']] to get a DataFrame, not a Series
exsisting['Credit_Limit_normalized'] = scaler.fit_transform(exsisting[['Credit_Limit']])
exsisting['Avg_Utilization_Ratio_normalized'] = scaler.fit_transform(exsisting[['Avg_Utilization_Ratio']])

exsisting.head()
# Out:
# C:\Users\nfs25\AppData\Local\Temp\ipykernel_22760\825149886.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exsisting['Credit_Limit_normalized'] = scaler.fit_transform(exsisting[['Credit_Limit']])
# C:\Users\nfs25\AppData\Local\Temp\ipykernel_22760\825149886.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exsisting['Avg_Utilization_Ratio_normalized'] = scaler.fit_transform(exsisting[['Avg_Utilization_Ratio']])
# ...

# %%
exsisting['Credit_Score'] = exsisting['Credit_Limit_normalized'] * exsisting['Avg_Utilization_Ratio_normalized']
# Out:
# C:\Users\nfs25\AppData\Local\Temp\ipykernel_22760\1551572321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exsisting['Credit_Score'] = exsisting['Credit_Limit_normalized'] * exsisting['Avg_Utilization_Ratio_normalized']

# %%
exsisting['Credit_Group'] = pd.cut(exsisting['Credit_Score'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1], labels=[0,1,2,3,4])
labels=['Very Low', 'Low', 'Medium', 'High', 'Very High']
credit_score_key = {labels[i]: i for i in range(len(labels))}
# Out:
# C:\Users\nfs25\AppData\Local\Temp\ipykernel_22760\178653548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exsisting['Credit_Group'] = pd.cut(exsisting['Credit_Score'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1], labels=[0,1,2,3,4])

# %%
cluster_data = df[df['Attrition_Flag'] == 1]

# %%
cluster_data.head()
# Out:
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               1            45       1                3
# 1  818770008               1            49       0                5
# 2  713982108               1            51       1                3
# 3  769911858               1            40       0                4
# 4  709106358               1            40       1                3
#
#    Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                3               1                2              0
# 1                2               2                4              0
# 2                2               1                3              0
# 3                3               3                4              0
# 4                5               1                2              0
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# ...
